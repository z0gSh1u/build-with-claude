# %% [markdown]
# # 02e - 基于模型的打分

# %%
from pprint import pprint
from statistics import mean
import json
from dotenv import load_dotenv
load_dotenv()
import os
# 检查 API Key 和 Base URL 是否已配置
bool(os.environ["ANTHROPIC_API_KEY"] and os.environ["BASE_URL"])
# Out:
# True

# %%
from anthropic import Anthropic

# 初始化 Anthropic 客户端
client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"], base_url=os.environ["BASE_URL"])
# 为了避免偏见，进行打分的模型通常应与生成回答的模型不同
# 因此这里从 Haiku 换成 Sonnet 4
model = "claude-sonnet-4-20250514"

# %%
def add_user_message(messages, text):
    """向消息列表中添加用户消息"""
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    """向消息列表中添加助手消息"""
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, **kwargs):
    """带着完整的消息列表发起对话请求并返回 Claude 的回复文本"""
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        **kwargs
    )
    return message.content[0].text

# %%
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def grade_by_model(test_case, output):
    task, solution = test_case, output
    eval_prompt = f"""
    You are an expert code reviewer. Evaluate this AI-generated solution.
    
    Task: {task}
    Solution: {solution}
    
    Provide your evaluation as a structured JSON object with:
    - "strengths": An array of 1-3 key strengths
    - "weaknesses": An array of 1-3 key areas for improvement  
    - "reasoning": A concise explanation of your assessment
    - "score": A number between 1-10
    """
    
    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_test_case(test_case):
    output = run_prompt(test_case)
    
    # 打分
    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    
    return {
        "output": output, 
        "test_case": test_case, 
        "score": score,
        "reasoning": reasoning
    }

# %%
def run_eval(dataset):
    """运行评估流程"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")
    
    return results

# %%
with open("02c-dataset.json", "r") as f:
    dataset = json.load(f)

dataset
# Out:
# [{'task': "Write a Python function that extracts the AWS region from an S3 bucket ARN string. For example, 'arn:aws:s3:::my-bucket' should return None, and 'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket' should return 'us-east-1'."},
#  {'task': 'Create a JSON object that represents an AWS IAM policy allowing a principal to perform s3:GetObject and s3:PutObject actions on a specific S3 bucket ARN (arn:aws:s3:::my-app-bucket/*).'},
#  {'task': "Write a Regex pattern that matches valid AWS EC2 instance IDs. Instance IDs follow the format 'i-' followed by exactly 17 hexadecimal characters (example: i-0a1b2c3d4e5f6g7h8)."}]

# %%
results = run_eval(dataset)
# Out:
# Average score: 8

# %%
results
# Out:
# [{'output': 'Looking at this task, I need to understand the structure of S3 ARNs and extract the region component.\n\nS3 ARNs can have different formats:\n1. Traditional bucket ARN: `arn:aws:s3:::bucket-name` (no region specified)\n2. S3 access point ARN: `arn:aws:s3:region:account-id:accesspoint/access-point-name`\n3. S3 object ARN: `arn:aws:s3:region:account-id:bucket/bucket-name`\n4. Other S3 resource ARNs that include region information\n\nThe general ARN format is: `arn:partition:service:region:account-id:resource`\n\nHere\'s my solution:\n\n```python\ndef extract_s3_region(arn):\n    """\n    Extracts the AWS region from an S3 bucket ARN string.\n    \n    Args:\n        arn (str): The S3 ARN string\n        \n    Returns:\n        str or None: The AWS region if present, None otherwise\n        \n    Examples:\n        extract_s3_region(\'arn:aws:s3:::my-bucket\') -> None\n        extract_s3_region(\'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket\') -> \'us-east-1\'\n    """\n    if not isinstance(arn, str):\n        return None\n    \n    # Split the ARN by colons\n    parts = arn.split(\':\')\n    \n    # Validate basic ARN structure\n    # ARN should have at least 6 parts: arn:partition:service:region:account:resource\n    if len(parts) < 6:\n        return None\n    \n    # Check if it\'s a valid AWS S3 ARN\n    if parts[0] != \'arn\' or parts[2] != \'s3\':\n        return None\n    \n    # Extract region (4th part, index 3)\n    region = parts[3]\n    \n    # Return None if region is empty, otherwise return the region\n    return region if region else None\n\n\n# Test the function\nif __name__ == "__main__":\n    # Test cases\n    test_cases = [\n        (\'arn:aws:s3:::my-bucket\', None),\n        (\'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket\', \'us-east-1\'),\n        (\'arn:aws:s3:eu-west-1:123456789012:accesspoint/my-access-point\', \'eu-west-1\'),\n        (\'arn:aws:s3:ap-southeast-2:123456789012:bucket/test-bucket\', \'ap-southeast-2\'),\n        (\'invalid-arn\', None),\n        (\'arn:aws:ec2:us-west-2:123456789012:instance/i-1234567890abcdef0\', None),\n        (\'\', None),\n        (\'arn:aws:s3::123456789012:bucket/my-bucket\', None),  # Empty region\n    ]\n    \n    for arn, expected in test_cases:\n        result = extract_s3_region(arn)\n        status = "✓" if result == expected else "✗"\n        print(f"{status} extract_s3_region(\'{arn}\') -> {result} (expected: {expected})")\n```\n\nThis function works by:\n\n1. **Input validation**: Checks if the input is a string\n2. **ARN parsing**: Splits the ARN by colons to get its components\n3. **Structure validation**: Ensures the ARN has at least 6 parts and is a valid S3 ARN\n4. **Region extraction**: Gets the region from the 4th position (index 3)\n5. **Empty region handling**: Returns `None` if the region field is empty (like in traditional bucket ARNs)\n\nThe function handles various S3 ARN formats and edge cases, returning the region when present or `None` when not available.',
#   'test_case': {'task': "Write a Python function that extracts the AWS region from an S3 bucket ARN string. For example, 'arn:aws:s3:::my-bucket' should return None, and 'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket' should return 'us-east-1'."},
#   'score': 8,
#   'reasoning': "This is a high-quality solution that demonstrates excellent understanding of AWS ARN formats and defensive programming practices. The code correctly handles the task requirements, includes comprehensive validation, and provides thorough testing. The implementation is robust and would work reliably in production. The weaknesses are minor optimization and naming considerations that don't affect functionality."},
#  {'output': 'Here\'s a JSON object representing an AWS IAM policy that allows the specified S3 actions on the given bucket:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-app-bucket/*"\n    }\n  ]\n}\n```\n\nThis IAM policy:\n\n- Uses the current policy language version (`2012-10-17`)\n- Grants `Allow` effect for the specified actions\n- Permits `s3:GetObject` (read/download objects) and `s3:PutObject` (write/upload objects) actions\n- Applies to all objects within the `my-app-bucket` S3 bucket (indicated by the `/*` suffix in the ARN)\n\n**Note:** This policy only grants permissions to objects within the bucket. If you also need to list objects in the bucket, you would need to add an additional statement with `s3:ListBucket` action on the bucket ARN `arn:aws:s3:::my-app-bucket` (without the `/*` suffix).',
#   'test_case': {'task': 'Create a JSON object that represents an AWS IAM policy allowing a principal to perform s3:GetObject and s3:PutObject actions on a specific S3 bucket ARN (arn:aws:s3:::my-app-bucket/*).'},
#   'score': 8,
#   'reasoning': "The solution correctly addresses the core requirements by creating a valid IAM policy with the exact actions and resource ARN specified. The JSON structure follows AWS standards and the explanation demonstrates good understanding of S3 permissions. The main limitation is not addressing the 'principal' aspect mentioned in the task description, though this could be interpreted as the policy being attached to a principal rather than embedded in the policy itself. The additional educational notes about ListBucket permissions show thoughtful consideration of practical use cases."},
#  {'output': "Looking at the requirements for AWS EC2 instance IDs:\n- Must start with 'i-'\n- Followed by exactly 17 hexadecimal characters\n- Hexadecimal characters are: 0-9, a-f, A-F\n\nHere's the regex pattern:\n\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\n**Breakdown:**\n- `^` - Start of string anchor\n- `i-` - Literal characters 'i-'\n- `[0-9a-fA-F]` - Character class for hexadecimal digits (0-9, lowercase a-f, uppercase A-F)\n- `{17}` - Exactly 17 occurrences of the preceding character class\n- `$` - End of string anchor\n\n**Alternative case-insensitive version:**\n```regex\n^i-[0-9a-f]{17}$\n```\n(Use this with case-insensitive flag if your regex engine supports it)\n\n**Test cases:**\n- ✅ Matches: `i-0a1b2c3d4e5f67890`\n- ✅ Matches: `i-1234567890abcdef1`\n- ❌ Doesn't match: `i-0a1b2c3d4e5f6789` (only 16 hex chars)\n- ❌ Doesn't match: `i-0a1b2c3d4e5f678901` (18 hex chars)\n- ❌ Doesn't match: `i-0a1b2c3d4e5f6g7h8` (contains 'g' and 'h' which aren't hex)",
#   'test_case': {'task': "Write a Regex pattern that matches valid AWS EC2 instance IDs. Instance IDs follow the format 'i-' followed by exactly 17 hexadecimal characters (example: i-0a1b2c3d4e5f6g7h8)."},
#   'score': 8,
#   'reasoning': "The solution demonstrates strong technical competency with a correct regex pattern, proper anchoring, and accurate character class definition. The breakdown and test cases are particularly valuable for understanding. However, there's a subtle issue where the solution doesn't explicitly call out that the example in the original task description contains invalid hexadecimal characters, which could confuse users. The solution correctly handles this in the test cases but could be more explicit about the discrepancy."}]
