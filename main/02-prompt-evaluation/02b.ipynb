# %% [markdown]
# # 02b - 典型的评估流程

# %%
from pprint import pprint
from dotenv import load_dotenv
load_dotenv()
import os
# 检查 API Key 和 Base URL 是否已配置
bool(os.environ["ANTHROPIC_API_KEY"] and os.environ["BASE_URL"])
# Out:
# True

# %%
from anthropic import Anthropic

# 初始化 Anthropic 客户端
client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"], base_url=os.environ["BASE_URL"])
# 本系列教程将使用 Claude Sonnet 4 模型
model = "claude-sonnet-4-20250514"

# %%
def add_user_message(messages, text):
    """向消息列表中添加用户消息"""
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    """向消息列表中添加助手消息"""
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, **kwargs):
    """带着完整的消息列表发起对话请求并返回 Claude 的回复文本"""
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        **kwargs
    )
    return message.content[0].text

# %%
questions = [
    "What's 2+2?",
    "How do I make oatmeal?",
    "How far away is the Moon?"
]

# %%
answers = []

for question in questions:
    prompt = f"""
Please answer the user's question:

{question}
"""
    messages = []
    add_user_message(messages, question)
    answer = chat(messages)
    answers.append(answer)

# %%
answers
# Out:
# ['2 + 2 = 4',
#  "Here's a simple way to make basic stovetop oatmeal:\n\n**Ingredients:**\n- 1 cup rolled oats (old-fashioned)\n- 2 cups water or milk (or a mix)\n- Pinch of salt\n\n**Instructions:**\n1. Bring the liquid and salt to a boil in a medium saucepan\n2. Add the oats and reduce heat to medium-low\n3. Simmer for 5-10 minutes, stirring occasionally, until creamy\n4. Remove from heat and let sit for 2-3 minutes to thicken\n\n**Quick alternatives:**\n- **Microwave**: Mix 1/2 cup oats with 1 cup liquid in a microwave-safe bowl. Microwave on high for 2-3 minutes, stirring halfway through\n- **Overnight oats**: Mix oats with liquid and refrigerate overnight (no cooking needed)\n\n**Popular toppings:**\n- Fresh fruit, nuts, honey, maple syrup, cinnamon, or brown sugar\n\nThe basic ratio is about 1:2 (oats to liquid), but adjust based on how thick you like it!",
#  "The Moon is approximately **384,400 kilometers** (238,855 miles) away from Earth on average.\n\nHowever, the Moon's distance varies because it follows an elliptical orbit:\n- **Closest approach (perigee)**: about 356,500 km (221,500 miles)\n- **Farthest point (apogee)**: about 406,700 km (252,700 miles)\n\nTo put this in perspective, you could fit about 30 Earth-sized planets in the space between Earth and the Moon!"]
