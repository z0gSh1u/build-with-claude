# %% [markdown]
# # 02d - 运行评测

# %%
from pprint import pprint
import json
from dotenv import load_dotenv
load_dotenv()
import os
# 检查 API Key 和 Base URL 是否已配置
bool(os.environ["ANTHROPIC_API_KEY"] and os.environ["BASE_URL"])
# Out:
# True

# %%
from anthropic import Anthropic

# 初始化 Anthropic 客户端
client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"], base_url=os.environ["BASE_URL"])
# 注意，我们在这里换用了相对廉价且快速的 haiku 4.5 模型
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    """向消息列表中添加用户消息"""
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    """向消息列表中添加助手消息"""
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, **kwargs):
    """带着完整的消息列表发起对话请求并返回 Claude 的回复文本"""
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        **kwargs
    )
    return message.content[0].text

# %%
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    output = run_prompt(test_case)
    # TODO 我们先使用一个硬编码的分数来走通流程，后续修改成实际的评分逻辑
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("02c-dataset.json", "r") as f:
    dataset = json.load(f)

dataset
# Out:
# [{'task': "Write a Python function that extracts the AWS region from an S3 bucket ARN string. For example, 'arn:aws:s3:::my-bucket' should return None, and 'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket' should return 'us-east-1'."},
#  {'task': 'Create a JSON object that represents an AWS IAM policy allowing a principal to perform s3:GetObject and s3:PutObject actions on a specific S3 bucket ARN (arn:aws:s3:::my-app-bucket/*).'},
#  {'task': "Write a Regex pattern that matches valid AWS EC2 instance IDs. Instance IDs follow the format 'i-' followed by exactly 17 hexadecimal characters (example: i-0a1b2c3d4e5f6g7h8)."}]

# %%
results = run_eval(dataset)

# %%
results
# Out:
# [{'output': '# Python Function to Extract AWS Region from S3 Bucket ARN\n\nHere\'s a comprehensive solution with multiple approaches:\n\n```python\ndef extract_region_from_s3_arn(arn: str) -> str | None:\n    """\n    Extract AWS region from an S3 bucket ARN string.\n    \n    Args:\n        arn: S3 bucket ARN string\n        \n    Returns:\n        Region string (e.g., \'us-east-1\') or None if not present\n        \n    Examples:\n        >>> extract_region_from_s3_arn(\'arn:aws:s3:::my-bucket\')\n        None\n        >>> extract_region_from_s3_arn(\'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket\')\n        \'us-east-1\'\n    """\n    try:\n        # ARN format: arn:partition:service:region:account-id:resource\n        parts = arn.split(\':\')\n        \n        # Check if ARN has the correct structure (at least 6 parts)\n        if len(parts) < 6:\n            return None\n        \n        # Region is the 4th element (index 3)\n        region = parts[3]\n        \n        # Return None if region is empty string\n        return region if region else None\n        \n    except (IndexError, AttributeError):\n        return None\n```\n\n## Alternative Regex Approach\n\n```python\nimport re\n\ndef extract_region_from_s3_arn_regex(arn: str) -> str | None:\n    """\n    Extract AWS region from S3 ARN using regex.\n    \n    Args:\n        arn: S3 bucket ARN string\n        \n    Returns:\n        Region string or None if not present\n    """\n    # Pattern matches: arn:aws:s3:REGION:ACCOUNT:...\n    match = re.match(r\'arn:aws:s3:([^:]*):.*\', arn)\n    \n    if match:\n        region = match.group(1)\n        return region if region else None\n    \n    return None\n```\n\n## Test Cases\n\n```python\ndef test_extract_region():\n    # Test cases\n    test_cases = [\n        (\'arn:aws:s3:::my-bucket\', None),\n        (\'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket\', \'us-east-1\'),\n        (\'arn:aws:s3:eu-west-1:123456789012:bucket/my-bucket\', \'eu-west-1\'),\n        (\'arn:aws:s3:ap-southeast-2:999999999999:bucket/test\', \'ap-southeast-2\'),\n        (\'arn:aws:s3:::bucket-without-region\', None),\n        (\'invalid-arn\', None),\n        (\'\', None),\n    ]\n    \n    for arn, expected in test_cases:\n        result = extract_region_from_s3_arn(arn)\n        status = "✓" if result == expected else "✗"\n        print(f"{status} extract_region_from_s3_arn(\'{arn}\') -> {result} (expected: {expected})")\n\n\nif __name__ == "__main__":\n    test_extract_region()\n```\n\n## Output\n\n```\n✓ extract_region_from_s3_arn(\'arn:aws:s3:::my-bucket\') -> None (expected: None)\n✓ extract_region_from_s3_arn(\'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket\') -> us-east-1 (expected: us-east-1)\n✓ extract_region_from_s3_arn(\'arn:aws:s3:eu-west-1:123456789012:bucket/my-bucket\') -> eu-west-1 (expected: eu-west-1)\n✓ extract_region_from_s3_arn(\'arn:aws:s3:ap-southeast-2:999999999999:bucket/test\')',
#   'test_case': {'task': "Write a Python function that extracts the AWS region from an S3 bucket ARN string. For example, 'arn:aws:s3:::my-bucket' should return None, and 'arn:aws:s3:us-east-1:123456789012:bucket/my-bucket' should return 'us-east-1'."},
#   'score': 10},
#  {'output': '# AWS IAM Policy for S3 GetObject and PutObject\n\nHere\'s a JSON object representing an AWS IAM policy that allows `s3:GetObject` and `s3:PutObject` actions on a specific S3 bucket:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-app-bucket/*"\n    }\n  ]\n}\n```\n\n## Explanation\n\n- **Version**: `"2012-10-17"` is the standard IAM policy language version\n- **Statement**: Array containing the policy rules\n- **Effect**: `"Allow"` grants the specified permissions\n- **Action**: Array of S3 actions:\n  - `s3:GetObject` - allows reading objects from the bucket\n  - `s3:PutObject` - allows writing/uploading objects to the bucket\n- **Resource**: The ARN specifying the target bucket and all objects within it (`/*`)\n\n## Additional Considerations\n\nIf you need to make this more restrictive or comprehensive, consider:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Sid": "AllowS3ObjectOperations",\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-app-bucket/*"\n    },\n    {\n      "Sid": "AllowListBucket",\n      "Effect": "Allow",\n      "Action": "s3:ListBucket",\n      "Resource": "arn:aws:s3:::my-app-bucket"\n    }\n  ]\n}\n```\n\nThis enhanced version includes:\n- `Sid` (Statement ID) for better readability and management\n- `s3:ListBucket` permission on the bucket itself (not the objects) to allow listing bucket contents',
#   'test_case': {'task': 'Create a JSON object that represents an AWS IAM policy allowing a principal to perform s3:GetObject and s3:PutObject actions on a specific S3 bucket ARN (arn:aws:s3:::my-app-bucket/*).'},
#   'score': 10},
#  {'output': '# AWS EC2 Instance ID Regex Pattern\n\nHere\'s the regex pattern that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string (anchor) |\n| `i-` | Literal "i-" prefix |\n| `[0-9a-f]` | Character class matching hexadecimal digits (0-9, a-f) |\n| `{17}` | Exactly 17 occurrences of the preceding character class |\n| `$` | End of string (anchor) |\n\n## Examples\n\n**Valid matches:**\n- `i-0a1b2c3d4e5f67890`\n- `i-1234567890abcdef0`\n- `i-ffffffffffffffff0`\n\n**Invalid (won\'t match):**\n- `i-0a1b2c3d4e5f6g7h8` ❌ (contains \'g\' and \'h\', not hex)\n- `i-0a1b2c3d4e5f678` ❌ (only 16 characters)\n- `i-0a1b2c3d4e5f6789012` ❌ (18 characters)\n- `0a1b2c3d4e5f67890` ❌ (missing \'i-\' prefix)\n\n## Implementation Examples\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nconsole.log(pattern.test(\'i-0a1b2c3d4e5f67890\')); // true\n```\n\n**Python:**\n```python\nimport re\npattern = r\'^i-[0-9a-f]{17}$\'\nprint(re.match(pattern, \'i-0a1b2c3d4e5f67890\'))  # Match object\n```',
#   'test_case': {'task': "Write a Regex pattern that matches valid AWS EC2 instance IDs. Instance IDs follow the format 'i-' followed by exactly 17 hexadecimal characters (example: i-0a1b2c3d4e5f6g7h8)."},
#   'score': 10}]
