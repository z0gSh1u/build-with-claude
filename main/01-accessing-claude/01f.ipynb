# %% [markdown]
# # 01f - 系统提示词

# %%
from pprint import pprint
from dotenv import load_dotenv
load_dotenv()
import os
# 检查 API Key 和 Base URL 是否已配置
bool(os.environ["ANTHROPIC_API_KEY"] and os.environ["BASE_URL"])
# Out:
# True

# %%
from anthropic import Anthropic

# 初始化 Anthropic 客户端
client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"], base_url=os.environ["BASE_URL"])
# 本系列教程将使用 Claude Sonnet 4 模型
model = "claude-sonnet-4-20250514"

# %%
# 没有系统提示词的情况
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "How do I solve 5x + 2 = 3 for x?"
        }
    ]
)

# %%
pprint(message.content[0].text)
# Out:
# ('To solve 5x + 2 = 3 for x, I need to isolate x by using inverse operations.\n'
#  '\n'
#  '**Step 1:** Subtract 2 from both sides\n'
#  '5x + 2 - 2 = 3 - 2\n'
#  '5x = 1\n'
#  '\n'
#  '**Step 2:** Divide both sides by 5\n'
#  '5x ÷ 5 = 1 ÷ 5\n'
#  'x = 1/5\n'
#  '\n'
#  '**Answer:** x = 1/5 (or x = 0.2)\n'
#  '\n'
#  '**Check:** Let me verify by substituting back into the original equation:\n'
#  '5(1/5) + 2 = 1 + 2 = 3 ✓')

# %%
# 有系统提示词的情况
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
message = client.messages.create(
    model=model,
    max_tokens=1000,
    system=system_prompt,
    messages=[
        {
            "role": "user",
            "content": "How do I solve 5x + 2 = 3 for x?"
        }
    ]
)

# %%
pprint(message.content[0].text)
# Out:
# ("Great question! Let's work through this step by step. \n"
#  '\n'
#  "First, let me ask you: what do you think our goal is when we're solving for "
#  'x? What do we want x to look like at the end?\n'
#  '\n'
#  'Once you think about that, look at the equation 5x + 2 = 3. What operation '
#  "is being done to x first, and what's being added to that result?")
