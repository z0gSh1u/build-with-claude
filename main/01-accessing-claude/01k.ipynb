# %% [markdown]
# # 01k - 控制模型输出

# %%
from pprint import pprint
from dotenv import load_dotenv
load_dotenv()
import os
# 检查 API Key 和 Base URL 是否已配置
bool(os.environ["ANTHROPIC_API_KEY"] and os.environ["BASE_URL"])
# Out:
# True

# %%
from anthropic import Anthropic

# 初始化 Anthropic 客户端
client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"], base_url=os.environ["BASE_URL"])
# 本系列教程将使用 Claude Sonnet 4 模型
model = "claude-sonnet-4-20250514"

# %%
def add_user_message(messages, text):
    """向消息列表中添加用户消息"""
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    """向消息列表中添加助手消息"""
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, **kwargs):
    """带着完整的消息列表发起对话请求并返回 Claude 的回复文本"""
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        **kwargs
    )
    return message.content[0].text

# %%
# 预填充助手消息
messages = []
add_user_message(messages, "Is tea or coffee better at breakfast?")
add_assistant_message(messages, "Coffee is better because")
answer = chat(messages)

# %%
pprint(answer)
# Out:
# (' it offers the caffeine you need to start the day. However, tea does have '
#  "its benefits for breakfast. Here's a quick comparison:\n"
#  '\n'
#  '**Coffee advantages:**\n'
#  '- Higher caffeine content for alertness\n'
#  '- Rich, robust flavor that pairs well with breakfast foods\n'
#  '- May boost metabolism\n'
#  '- Familiar morning ritual for many people\n'
#  '\n'
#  '**Tea advantages:**\n'
#  '- Gentler caffeine boost (less jittery)\n'
#  '- Contains antioxidants and other beneficial compounds\n'
#  '- Lighter on the stomach\n'
#  '- Wide variety of flavors and types\n'
#  '- Often less acidic than coffee\n'
#  '\n'
#  'The "better" choice really depends on your personal preferences, caffeine '
#  'tolerance, and how each affects your digestion in the morning. Some people '
#  'find coffee too harsh on an empty stomach, while others need that stronger '
#  'caffeine kick to feel alert.\n'
#  '\n'
#  'What matters most is which one you enjoy and which helps you feel your best '
#  'to start the day!')

# %%
# 提供停止序列
messages = []
add_user_message(messages, "Count from 1 to 10")
answer = chat(messages, stop_sequences=["5"])

# %%
answer
# Out:
# '1, 2, 3, 4, '
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
